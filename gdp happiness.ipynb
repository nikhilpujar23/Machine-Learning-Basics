# %%
import sklearn
assert sklearn.__version__ >= "0.20"
import pandas as pd
import numpy as np

# %%
gdp=pd.read_csv(r'D:\4th sem\machine learning/gdp per capita.csv', na_values="n/a")

# %%
gdp[1:6]
# Out:
#                   Country Name Country Code  \
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
# 5                      Albania          ALB
#
#                                   Indicator Name     Indicator Code  1960  \
# 1  GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD   NaN
# 2  GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD   NaN
# 3  GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD   NaN
# 4  GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD   NaN
# 5  GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD   NaN
#
#           1990         1991         1992         1993         1994  ...  \
# 1  1853.584807  1865.700248  1821.675395  1811.827790  1835.494768  ...
# 2          NaN          NaN          NaN          NaN          NaN  ...
# ...

# %%
h_index=pd.read_csv(r'D:\4th sem\machine learning/BLI.csv',thousands=',')

# %%
h_index
# Out:
#      LOCATION         Country INDICATOR                          Indicator  \
# 0         AUS       Australia   JE_LMIS           Labour market insecurity
# 1         AUT         Austria   JE_LMIS           Labour market insecurity
# 2         BEL         Belgium   JE_LMIS           Labour market insecurity
# 3         CAN          Canada   JE_LMIS           Labour market insecurity
# 4         CZE  Czech Republic   JE_LMIS           Labour market insecurity
# ...       ...             ...       ...                                ...
# 2364      LTU       Lithuania   WL_EWLH  Employees working very long hours
# 2365      COL        Colombia   WL_EWLH  Employees working very long hours
# 2366      LTU       Lithuania   WL_EWLH  Employees working very long hours
# 2367      COL        Colombia   WL_EWLH  Employees working very long hours
# 2368      LTU       Lithuania   WL_EWLH  Employees working very long hours
#
#      MEASURE Measure INEQUALITY Inequality Unit Code        Unit  \
# ...

# %%
gdp.rename(columns={'2015':'Gdp_per_capita'},inplace=True)

# %%
gdp.set_index('Country Name',inplace=True)

# %%
gdp.index
# Out:
# Index(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina',
#        ...
#        'Virgin Islands (U.S.)', 'Vietnam', 'Vanuatu', 'World', 'Samoa',
#        'Kosovo', 'Yemen, Rep.', 'South Africa', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country Name', length=266)

# %%
h_index=h_index[h_index['INEQUALITY']=='TOT']
h_index
# Out:
#      LOCATION         Country INDICATOR                          Indicator  \
# 0         AUS       Australia   JE_LMIS           Labour market insecurity
# 1         AUT         Austria   JE_LMIS           Labour market insecurity
# 2         BEL         Belgium   JE_LMIS           Labour market insecurity
# 3         CAN          Canada   JE_LMIS           Labour market insecurity
# 4         CZE  Czech Republic   JE_LMIS           Labour market insecurity
# ...       ...             ...       ...                                ...
# 2350      LTU       Lithuania   SW_LIFS                  Life satisfaction
# 2357      COL        Colombia   PS_REPH                      Homicide rate
# 2358      LTU       Lithuania   PS_REPH                      Homicide rate
# 2363      COL        Colombia   WL_EWLH  Employees working very long hours
# 2364      LTU       Lithuania   WL_EWLH  Employees working very long hours
#
# ...

# %%
h_index = h_index.pivot(index="Country" , columns="Indicator", values="Value")

# %%
h_index
# Out:
# Indicator        Air pollution  Dwellings without basic facilities  \
# Country
# Australia                  5.0                                 NaN
# Austria                   16.0                                 0.9
# Belgium                   15.0                                 1.9
# Brazil                    10.0                                 6.7
# Canada                     7.0                                 0.2
# Chile                     16.0                                 9.4
# Colombia                  10.0                                23.9
# Czech Republic            20.0                                 0.7
# Denmark                    9.0                                 0.5
# Estonia                    8.0                                 7.0
# Finland                    6.0                                 0.5
# France                    13.0                                 0.5
# Germany                   14.0                                 0.2
# ...

# %%
df=pd.merge(
left=h_index,right=gdp,left_index=True,right_index=True
)
df=df[["Gdp_per_capita", 'Life satisfaction']]
df
# Out:
#                  Gdp_per_capita  Life satisfaction
# Australia           46248.61646                7.3
# Austria             49865.90394                7.1
# Belgium             46200.90445                6.9
# Brazil              14744.11363                6.4
# Canada              44670.08054                7.4
# Chile               22698.54566                6.5
# Colombia            13265.79726                6.3
# Czech Republic      33899.28657                6.7
# Denmark             49045.33919                7.6
# Estonia             29175.92593                5.7
# Finland             42497.70498                7.6
# France              40849.99738                6.5
# Germany             47609.78100                7.0
# Greece              26760.36330                5.4
# Hungary             26806.59525                5.6
# Iceland             49201.06410                7.5
# Ireland             69028.77272                7.0
# ...

# %%
import matplotlib.pyplot as plt

X=np.c_[df['Gdp_per_capita']]
Y=np.c_[df['Life satisfaction']]
df.plot(kind='scatter',x='Gdp_per_capita',y='Life satisfaction')
plt.show()

#np.array won't work

# %%
print(X,Y)
# Out:
# [[ 46248.61646]
#  [ 49865.90394]
#  [ 46200.90445]
#  [ 14744.11363]
#  [ 44670.08054]
#  [ 22698.54566]
#  [ 13265.79726]
#  [ 33899.28657]
#  [ 49045.33919]
#  [ 29175.92593]
#  [ 42497.70498]
#  [ 40849.99738]
#  [ 47609.781  ]
#  [ 26760.3633 ]
#  [ 26806.59525]
#  [ 49201.0641 ]
#  [ 69028.77272]
#  [ 35469.9502 ]
#  [ 36899.38521]
#  [ 40898.80697]
#  [ 24972.78609]
#  [ 28834.42768]
#  [107859.686  ]
#  [ 18301.50047]
#  [ 50288.59139]
#  [ 37479.68298]
#  [ 60368.92087]
#  [ 26862.05252]
#  [ 29660.89607]
#  [ 29964.88861]
#  [ 31628.24718]
#  [ 13701.94539]
#  [ 34903.12748]
#  [ 49103.13343]
#  [ 66020.20434]
#  [ 25753.39051]
#  [ 42912.87509]
#  [ 56863.3715 ]] [[7.3]
#  [7.1]
#  [6.9]
#  [6.4]
#  [7.4]
#  [6.5]
#  [6.3]
#  [6.7]
#  [7.6]
#  [5.7]
#  [7.6]
#  [6.5]
#  [7. ]
#  [5.4]
#  [5.6]
#  [7.5]
#  [7. ]
#  [7.2]
#  [6. ]
#  [5.9]
#  [5.9]
#  [5.9]
#  [6.9]
#  [6.5]
#  [7.4]
#  [7.3]
#  [7.6]
#  [6.1]
#  [5.4]
#  [6.2]
#  [5.9]
#  [4.7]
#  [6.3]
#  [7.3]
#  [7.5]
# ...

# %%
import sklearn.linear_model
model = sklearn.linear_model.LinearRegression()
# Train the model
model.fit(X, Y)
# Make a prediction for Cyprus
X_new = [[22587]] 
print(model.predict(X_new))
# Out:
# [[6.1425732]]

# %%
import sklearn.neighbors
model=sklearn.neighbors.KNeighborsRegressor(n_neighbors=3)
x_new=[[22587]]
model.fit(X,Y)
print(model.predict(x_new))
# Out:
# [[5.96666667]]
